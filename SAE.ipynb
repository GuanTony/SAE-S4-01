# %%
pip install mysql-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.32-cp39-cp39-manylinux1_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in /usr/local/lib/python3.9/dist-packages (from mysql-connector-python) (3.19.6)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.0.32

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

import mysql.connector as MC

try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()

  req = 'SELECT Etablissement, COUNT(*) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and a.`Mange Matin` = "oui" GROUP BY Etablissement'
  cursor.execute(req)

  data = {}
  for i in cursor.fetchall():
    data[i[0]] = i[1]

except MC.Error as err:
  print(err)


fig, ax = plt.subplots()
ax.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax.legend(title = "Nombres d'étudiants qui mangent le matin en fonction de leurs niveaux", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.1),  labels=data.keys())

plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()

except MC.Error as err:
  print(err)

fig, ax = plt.subplots()

req = 'SELECT Age, COUNT(*) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = "Lycee" GROUP BY Age ORDER BY AGE ASC'
cursor.execute(req)
result = cursor.fetchall()

age = []
nombres_personnes = []

for row in result:
  age.append(row[0])
  nombres_personnes.append(row[1])

ax.bar(age, nombres_personnes, 0.35, color = 'red')

req1 = 'SELECT Age, COUNT(*) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = "College" GROUP BY Age ORDER BY AGE ASC'
cursor.execute(req1)
result1 = cursor.fetchall()

age1 = []
nombres_personnes1 = []

for row in result1:
  age1.append(row[0])
  nombres_personnes1.append(row[1])


position = np.arange(len(age))
largeur = .35


ax.bar(age1, nombres_personnes1, 0.35, align = 'edge')

Niveaux = ["Lycée", "College"]
plt.xlabel('Age')
plt.ylabel('Nombres de personnes')
plt.title("Nombres de personnes qui mangent le matin par tranche d'âge")
plt.legend(Niveaux)
plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()


except MC.Error as err:
  print(err)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
req1 = 'SELECT Entree, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "Lycee" GROUP BY Entree ORDER BY 1'
cursor.execute(req1)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax1.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax1.legend(title = "Types d'entree les plus choisies parmi les collégiens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

req2 = 'SELECT Entree, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "College" GROUP BY Entree ORDER BY 1'
cursor.execute(req2)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax2.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax2.legend(title = "Types d'entree les plus choisies parmi les lycéens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

plt.subplots_adjust(right=2.1, wspace=0.2, top=0.85)

plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()



except MC.Error as err:
  print(err)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
req1 = 'SELECT Poisson, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "Lycee" GROUP BY Poisson ORDER BY 1'
cursor.execute(req1)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax1.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax1.legend(title = "Types de poisson les plus choisies parmi les collégiens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

req2 = 'SELECT Poisson, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "College" GROUP BY Poisson ORDER BY 1'
cursor.execute(req2)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax2.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax2.legend(title = "Types de poisson les plus choisies parmi les lycéens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

plt.subplots_adjust(right=2, wspace=0.2, top=0.85)

plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()



except MC.Error as err:
  print(err)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(7, 6))
req1 = 'SELECT Viande, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "Lycee" GROUP BY Viande ORDER BY 1'
cursor.execute(req1)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax1.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax1.legend(title = "Types de viande les plus choisies parmi les collégiens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

req2 = 'SELECT Viande, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "College" GROUP BY Viande ORDER BY 1'
cursor.execute(req2)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax2.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax2.legend(title = "Types de viande les plus choisies parmi les lycéens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.3),  labels=data.keys())

plt.subplots_adjust(right=2, wspace=0.2, top=0.85)

plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()



except MC.Error as err:
  print(err)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8,8))
req1 = 'SELECT Compose, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "Lycee" GROUP BY Compose ORDER BY 1'
cursor.execute(req1)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax1.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax1.legend(title = "Types de compose les plus choisies parmi les collégiens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.2),  labels=data.keys())

req2 = 'SELECT Compose, COUNT(*) FROM `info perso` as i, aliments as a WHERE i.ID = a.ID and i.Etablissement = "College" GROUP BY Compose ORDER BY 1'
cursor.execute(req2)

data = {}
for i in cursor.fetchall():
  data[i[0]] = i[1] 

ax2.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax2.legend(title = "Types de compose les plus choisies parmi les lycéens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.2),  labels=data.keys())

plt.subplots_adjust(right=2, wspace=0.2, top=0.85)
plt.show()

# %%
try:
  conn = MC.connect(host = 'sql.freedb.tech', database = 'freedb_SAE-S4', user ='freedb_TonyG', password = '8wrGdDJqKu@5Ug5')
  cursor = conn.cursor()



except MC.Error as err:
  print(err)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8,8))

req1 = "SELECT COUNT(Fruit) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Fruit = 'Oui'"
cursor.execute(req1)


for i in cursor.fetchall():
  data1 = i[0]

req2 = "SELECT COUNT(Boisson) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Boisson = 'Oui'"
cursor.execute(req2)


for i in cursor.fetchall():
  data2 = i[0]

req3 = "SELECT COUNT(`Produit Laitier`) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and `Produit Laitier` = 'Oui'"
cursor.execute(req3)


for i in cursor.fetchall():
  data3 = i[0]

req4 = "SELECT COUNT(Charcuterie) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Charcuterie = 'Oui'"
cursor.execute(req4)


for i in cursor.fetchall():
  data4 = i[0]

req5 = "SELECT COUNT(Oeuf) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Oeuf = 'Oui'"
cursor.execute(req5)


for i in cursor.fetchall():
  data5 = i[0]

req6 = "SELECT COUNT(Cereales) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Cereales = 'Oui'"
cursor.execute(req6)


for i in cursor.fetchall():
  data6 = i[0]

req7 = "SELECT COUNT(Patisserie) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'Lycee' and Patisserie = 'Oui'"
cursor.execute(req7)


for i in cursor.fetchall():
  data7 = i[0]

data = {}
data["Fruit"] = data1
data["Boisson"] = data2
data["Produit Laitier"] = data3
data["Charcuterie"] = data4  
data["Oeuf"] = data5
data["Cereales"] = data6  
data["Patisserie"] = data7  

ax1.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax1.legend(title = "Petit dejeuné les plus choisies parmi les lyceens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.2),  labels=data.keys())

req10 = "SELECT COUNT(Fruit) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Fruit = 'Oui'"
cursor.execute(req10)


for i in cursor.fetchall():
  data10 = i[0]

req20 = "SELECT COUNT(Boisson) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Boisson = 'Oui'"
cursor.execute(req20)


for i in cursor.fetchall():
  data20 = i[0]

req30 = "SELECT COUNT(`Produit Laitier`) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and `Produit Laitier` = 'Oui'"
cursor.execute(req30)


for i in cursor.fetchall():
  data30 = i[0]

req40 = "SELECT COUNT(Charcuterie) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Charcuterie = 'Oui'"
cursor.execute(req40)


for i in cursor.fetchall():
  data40 = i[0]

req50 = "SELECT COUNT(Oeuf) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Oeuf = 'Oui'"
cursor.execute(req50)


for i in cursor.fetchall():
  data50 = i[0]

req60 = "SELECT COUNT(Cereales) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Cereales = 'Oui'"
cursor.execute(req60)


for i in cursor.fetchall():
  data60 = i[0]

req70 = "SELECT COUNT(Patisserie) FROM `info perso` as i, alimentation as a WHERE i.ID = a.ID and i.Etablissement = 'College' and Patisserie = 'Oui'"
cursor.execute(req70)


for i in cursor.fetchall():
  data70 = i[0]

data = {}
data["Fruit"] = data10
data["Boisson"] = data20
data["Produit Laitier"] = data30
data["Charcuterie"] = data40
data["Oeuf"] = data50
data["Cereales"] = data60
data["Patisserie"] = data70

ax2.pie(data.values(), autopct = '%1.2f%%', shadow =True)
ax2.legend(title = "Petit dejeuné les plus choisies parmi les collegiens", title_fontsize=(14), loc='center', bbox_to_anchor=(0.5, 1.2),  labels=data.keys())

plt.subplots_adjust(right=2, wspace=0.2, top=0.85)
plt.show()
